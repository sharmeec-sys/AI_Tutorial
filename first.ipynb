# %%
a=3

# %%
file = open("notes.txt",'r')
content = file.read()
print(content)
# Out:
# This is sample file.

# %%
file = open("notes.txt",'a')
file.write("\n Content added more")
file.close()
file = open("notes.txt",'r')
content = file.read()
file.close()
print(content)
# Out:
# This is sample file.
#  Content added more

# %%
import os
os.getcwd()
os.listdir()
# Out:
# ['first.ipynb', 'notes.txt', 'sharmi', 'Test', 'Test.py']
